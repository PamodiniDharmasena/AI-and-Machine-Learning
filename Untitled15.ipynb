# %% [markdown]
# <a href="https://colab.research.google.com/github/VirajDilshanKumarage/AI-and-Machine-Learning/blob/logistic_regression/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("logistic.csv")

# %%
data.tail()
# Out:
#    age  job
# 4   40    0
# 5   34    1
# 6   18    0
# 7   56    1
# 8   23    1

# %%
plt.scatter(data[['age']],data[['job']])

# %%
x=data[['age']]
y=data[['job']]

# %%
x
# Out:
#    age
# 0   12
# 1   20
# 2   23
# 3   25
# 4   40
# 5   34
# 6   18
# 7   56
# 8   23

# %%
y
# Out:
#    job
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# 5    1
# 6    0
# 7    1
# 8    1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# %%
x_train
# Out:
#    age
# 1   20
# 2   23
# 5   34
# 3   25
# 6   18

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 1, 1, 0])

# %%
x_test
# Out:
#    age
# 8   23
# 7   56
# 4   40
# 0   12

# %%
y_test
# Out:
#    job
# 8    1
# 7    1
# 4    0
# 0    0

# %%
model.score(x_test,y_test)
# Out:
# 0.75

# %%
model.predict([[45]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
ages=np.array([[31],[23],[11]])

# %%
model.predict(ages)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1, 1, 0])
