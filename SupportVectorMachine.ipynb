# %% [markdown]
# <a href="https://colab.research.google.com/github/VirajDilshanKumarage/AI-and-Machine-Learning/blob/SupportVectorMachine/SupportVectorMachine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## support vector machine

# %% [markdown]
# select hte best hyperplane

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# let assume model that capable to classification of iris flower
#
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
data =pd.read_csv('Iris.csv')
data.sample(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 34  35            4.9           3.1            1.5           0.1
# 84  85            5.4           3.0            4.5           1.5
# 16  17            5.4           3.9            1.3           0.4
# 79  80            5.7           2.6            3.5           1.0
# 52  53            6.9           3.1            4.9           1.5
#
#             Species
# 34      Iris-setosa
# 84  Iris-versicolor
# 16      Iris-setosa
# 79  Iris-versicolor
# 52  Iris-versicolor

# %%
data=data.drop('Id',axis=1)
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
import seaborn as sns
sns.pairplot(data,hue='Species')

# %%
x=data.drop('Species',axis=1)

# %%
x.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 57             4.9           2.4            3.3           1.0
# 120            6.9           3.2            5.7           2.3
# 39             5.1           3.4            1.5           0.2
# 45             4.8           3.0            1.4           0.3
# 29             4.7           3.2            1.6           0.2

# %%
y=data['Species']
y.sample(5)
# Out:
# 116     Iris-virginica
# 130     Iris-virginica
# 61     Iris-versicolor
# 29         Iris-setosa
# 64     Iris-versicolor
# Name: Species, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC
model=SVC(kernel='poly')
model.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
model.kernel
# Out:
# 'poly'

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array(['Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica'], dtype=object)

# %%
y_test
# Out:
# 56     Iris-versicolor
# 25         Iris-setosa
# 39         Iris-setosa
# 134     Iris-virginica
# 141     Iris-virginica
# 17         Iris-setosa
# 119     Iris-virginica
# 85     Iris-versicolor
# 15         Iris-setosa
# 117     Iris-virginica
# 75     Iris-versicolor
# 123     Iris-virginica
# 74     Iris-versicolor
# 65     Iris-versicolor
# 98     Iris-versicolor
# 32         Iris-setosa
# 144     Iris-virginica
# 130     Iris-virginica
# 142     Iris-virginica
# 71     Iris-versicolor
# 145     Iris-virginica
# 96     Iris-versicolor
# 16         Iris-setosa
# 53     Iris-versicolor
# 106     Iris-virginica
# 48         Iris-setosa
# 7          Iris-setosa
# 94     Iris-versicolor
# 107     Iris-virginica
# 112     Iris-virginica
# Name: Species, dtype: object

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(pred,y_test)
# Out:
# 0.9333333333333333

# %%
confusion_matrix(pred,y_test)
# Out:
# array([[ 8,  0,  0],
#        [ 0, 10,  2],
#        [ 0,  0, 10]])
