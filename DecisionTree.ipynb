# %% [markdown]
# <a href="https://colab.research.google.com/github/VirajDilshanKumarage/AI-and-Machine-Learning/blob/Decision-Tree-algorithm/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Decision Tree Algorithm

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# let's suppose that there are children who consider the weather condition to play
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# and let suppose that, the considered temperature as 30 (C)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# in order to select best decision tree we can use three methods such as
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# then we must select the minimum entropy value as suitable decision tree algorithm

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('kyphosis.csv')

# %%
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
x=data.drop('Kyphosis',axis=1)

# %%
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y=data['Kyphosis']

# %%
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (56, 3)

# %%
x_test.shape
# Out:
# (25, 3)

# %%
#Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=model.predict(x_test)
pred
# Out:
# array(['present', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'present', 'absent', 'absent', 'absent', 'present', 'present',
#        'absent', 'present', 'absent', 'absent', 'absent', 'absent',
#        'present', 'present', 'present', 'present', 'absent', 'absent',
#        'absent'], dtype=object)

# %%
y_test
# Out:
# 57    present
# 56     absent
# 33     absent
# 51     absent
# 54     absent
# 9     present
# 2     present
# 16     absent
# 11     absent
# 37    present
# 39    present
# 60    present
# 80     absent
# 77     absent
# 32     absent
# 78     absent
# 47     absent
# 14     absent
# 79    present
# 67     absent
# 21    present
# 23     absent
# 40    present
# 52    present
# 53     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.72

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[12,  3],
#        [ 4,  6]])
