# %% [markdown]
# <a href="https://colab.research.google.com/github/VirajDilshanKumarage/AI-and-Machine-Learning/blob/K-mean-clustering/K_mean_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # *STEP 1*

# %% [markdown]
# Determine the K value
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # *Step 2*

# %% [markdown]
# select the random point among the data point
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # step 3

# %% [markdown]
# then divid the data point into K bnumber of categories by considering the distance of the data point and consider random point

# %% [markdown]
# then find the central point of the categorized data points separately

# %% [markdown]
# # step 4

# %% [markdown]
# repeat the step 3 until find the cetral point (which not change further) of the categorized data points
#
# ![image.png](data:image/png;base64,...)
#
# then final output ---->
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# sometime we can cluster our data set into various cluster but there is a best 'number of cluster' avaliable. So how to choose the best K value..
# for that we can use Elbow method
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# if K=1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# then calculate the WCSS Error when K=1
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# then select the optimal value that show the biggest slope change in the graph and K value of the optimal point will be the Best K value
#
# ![image.png](data:image/png;base64,...)
