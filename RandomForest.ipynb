# %% [markdown]
# <a href="https://colab.research.google.com/github/VirajDilshanKumarage/AI-and-Machine-Learning/blob/Random-Forest-Algorithm/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# random forest

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('kyphosis.csv')

# %%
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
x=data.drop('Kyphosis',axis=1)

# %%
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y=data['Kyphosis']

# %%
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (56, 3)

# %%
x_test.shape
# Out:
# (25, 3)

# %%
#Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array(['absent', 'absent', 'present', 'absent', 'present', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'present', 'present', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'present', 'absent',
#        'present'], dtype=object)

# %%
y_test
# Out:
# 77     absent
# 41     absent
# 61    present
# 34     absent
# 59     absent
# 17     absent
# 66     absent
# 73     absent
# 65     absent
# 31     absent
# 32     absent
# 14     absent
# 43     absent
# 35     absent
# 56     absent
# 27     absent
# 48    present
# 12     absent
# 29     absent
# 24    present
# 78     absent
# 20     absent
# 45    present
# 74     absent
# 21    present
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.88

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[18,  2],
#        [ 1,  4]])

# %%
#Random forest

from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=50)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
RandomForestClassifier(n_estimators=50)
pred=model.predict(x_test)
pred
# Out:
# array(['absent', 'absent', 'present', 'absent', 'present', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'present'], dtype=object)

# %%
y_test
# Out:
# 77     absent
# 41     absent
# 61    present
# 34     absent
# 59     absent
# 17     absent
# 66     absent
# 73     absent
# 65     absent
# 31     absent
# 32     absent
# 14     absent
# 43     absent
# 35     absent
# 56     absent
# 27     absent
# 48    present
# 12     absent
# 29     absent
# 24    present
# 78     absent
# 20     absent
# 45    present
# 74     absent
# 21    present
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.84

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[19,  1],
#        [ 3,  2]])
